# %% [markdown]
# <a href="https://colab.research.google.com/github/tiagopessoalima/ED1/blob/main/Semana_02_(ED1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **O que são Algoritmos de Ordenação?**

# %% [markdown]
# Os algoritmos de ordenação são conjuntos de passos lógicos e bem definidos que organizam um conjunto de elementos em uma ordem específica. Na ciência da computação, a ordenação é uma operação fundamental, uma vez que permite que dados sejam organizados de maneira eficiente para facilitar a busca, análise e manipulação.

# %% [markdown]
# # **Importância dos Algoritmos de Ordenação**

# %% [markdown]
# - **Bancos de Dados**: Os dados em um banco de dados frequentemente precisam ser recuperados em uma ordem específica. Algoritmos de ordenação são usados para organizar dados em tabelas de bancos de dados.
#
# - **Aplicações Web**: Muitas aplicações *web* exibem listas de informações em ordens específicas, como listas de produtos em uma loja *online*. Algoritmos de ordenação garantem que essas informações sejam apresentadas de forma organizada.
#
# - **Processamento de Dados**: Dados brutos frequentemente precisam ser organizados antes de serem processados. Algoritmos de ordenação são usados para preparar os dados para análise subsequente.
#
# - **Algoritmos de Busca Eficiente**: Algoritmos de ordenação são frequentemente usados como parte de algoritmos de busca eficiente, como a busca binária, que requer que os dados estejam ordenados.

# %% [markdown]
# # **Métricas de Avaliação**

# %% [markdown]
# Ao escolher um algoritmo de ordenação para uma determinada tarefa, várias métricas de avaliação são consideradas:
#
# - **Complexidade Temporal**: Refere-se ao tempo de execução do algoritmo. Algoritmos mais eficientes têm menor complexidade temporal, o que é crucial para ordenar grandes conjuntos de dados.
#
# - **Complexidade Espacial**: Refere-se à quantidade de memória adicional usada pelo algoritmo. Algoritmos com menor complexidade espacial usam menos memória, o que é importante em sistemas com restrições de memória.
#
# - **Estabilidade**: Algoritmos estáveis preservam a ordem relativa dos elementos com chaves iguais. Isso é importante em cenários onde múltiplos critérios de ordenação são aplicados sequencialmente.

# %% [markdown]
# # **Métodos de Ordenação**

# %% [markdown]
# Os algoritmos de ordenação podem ser classificados em dois grupos, com base na disponibilidade de memória para realizar a ordenação:

# %% [markdown]
# ## **Ordenação Interna**

# %% [markdown]
# Todos os elementos a serem ordenados cabem na memória principal (RAM) do computador. Isso permite que qualquer registro seja acessado rapidamente, tornando a ordenação mais eficiente. Os métodos de ordenação interna podem ser divididos em dois subgrupos:
#
# - **Métodos Simples**: Esses métodos são adequados para pequenos conjuntos de dados e são relativamente fáceis de implementar e entender. No entanto, eles têm complexidade quadrática, o que significa que podem se tornar lentos para grandes volumes de dados. Exemplos incluem o *Bubble Sort*, o *Insertion Sort*, o *Selection Sort* e o *Comb Sort*.
#
# - **Métodos Eficientes**: Esses métodos são mais complexos em termos de detalhes, mas oferecem melhor desempenho para conjuntos de dados maiores. Eles têm uma complexidade logarítmica, tornando-os mais rápidos para grandes volumes de dados. Alguns exemplos populares são o *Quick Sort*, o *Merge Sort*, o *Heap Sort*, o *Shell Sort* e o *TimSort*.

# %% [markdown]
# ## **Ordenação Externa**

# %% [markdown]
# Os elementos a serem ordenados não cabem na memória principal e precisam ser acessados sequencialmente ou em grandes blocos. Isso é comum quando você precisa ordenar grandes volumes de dados que não podem ser carregados completamente na memória RAM. A ordenação externa é mais complexa e envolve leitura e gravação de dados em dispositivos de armazenamento secundário, como discos rígidos. Algoritmos como o *Merge Sort* e o *Polyphase Sort* são usados para lidar com a ordenação externa.

# %% [markdown]
# # **Algoritmos**

# %% [markdown]
# Existem muitos algoritmos de ordenação já desenvolvidos e analisados. Neste material, exploraremos diversas técnicas de ordenação já estabelecidas, comparando-as com base em suas eficiências de tempo de execução.

# %% [markdown]
# ## **[Bubble Sort](https://www.youtube.com/watch?v=Iv3vgjM8Pv4)**

# %% [markdown]
# É um dos algoritmos de ordenação mais simples, mas também um dos menos eficientes em termos de desempenho. Funciona comparando pares de elementos adjacentes e trocando-os se estiverem fora de ordem. Esse processo é repetido várias vezes até que a lista inteira esteja ordenada. A figura abaixo ilustra a primeira passada do algoritmo para ordenar uma lista com os elementos 54, 26, 93, 17, 77, 31, 44, 55 e 20.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Obs**: na segunda passagem, o maior valor já estará em sua posição correta. Como cada passagem posiciona o próximo maior valor no lugar adequado, o número total de passagens requeridas para ordenar um vetor de tamanho $n$ será $n-1$.

# %% [markdown]
# ###***Swap***

# %% [markdown]
# A troca de dois elementos numa lista requer o uso de uma variável para armazenamento temporário, conforme trecho de código abaixo:

# %%
numbers = [93, 58, 44]  # Lista de números: [93, 58, 44]

temp = numbers[0]  # Armazena temporariamente o valor 93
numbers[0] = numbers[2]  # Substitui o primeiro valor pelo último: [44, 58, 44]
numbers[2] = temp  # Substitui o último valor pelo temporário (93): [44, 58, 93]

print(numbers)  # Saída: [44, 58, 93]
# Out:
# [44, 58, 93]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Porém, em *Python*, é possível realizar atribuições simultâneas, conforme exemplo abaixo:

# %%
numbers = [93, 58, 44]  # Lista de números: [93, 58, 44]

numbers[0], numbers[2] = numbers[2], numbers[0]

print(numbers)  # Saída: [44, 58, 93]
# Out:
# [44, 58, 93]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###**Implementação**

# %% [markdown]
# Aqui está uma descrição passo a passo do raciocínio por trás do *Bubble Sort*:
#
# 1. **Comparação de elementos adjacentes:** O algoritmo começa comparando o primeiro elemento com o segundo elemento do vetor. Se o primeiro elemento for maior do que o segundo, eles são trocados de posição.
#
# 2. **Movendo pelo vetor:** O algoritmo então avança para a próxima dupla de elementos adjacentes (segundo e terceiro), compara-os e os troca, se necessário. Esse processo continua até que o último par de elementos seja comparado.
#
# 3. **Primeira passagem completa:** Após a primeira passagem pelo vetor, o maior elemento terá "borbulhado" para a última posição. Isso ocorre porque em cada comparação, o elemento maior é movido para a direita.
#
# 4. **Segunda passagem:** O algoritmo reinicia a passagem desde o início do vetor, comparando e trocando elementos adjacentes conforme necessário. Nessa passagem, o segundo maior elemento encontrará sua posição.
#
# 5. **Passagens subsequentes:** O algoritmo continua repetindo as passagens pelo vetor até que não seja mais necessário trocar elementos. Isso acontece quando nenhum elemento precisa ser trocado em uma passagem completa.
#
# 6. **Vetor ordenado:** No final das passagens, todos os elementos estarão em suas posições corretas, e o vetor estará ordenado do menor para o maior.

# %% [markdown]
# #### **Primeira Implementação (não otimizada)**

# %% [markdown]
# O *Bubble Sort* é um dos algoritmos de ordenação mais simples e diretos. Ele recebe esse nome porque os elementos "borbulham" através do vetor conforme são comparados e trocados de posição, até que todos os elementos estejam em sua posição correta. Observe abaixo:

# %%
def bubble_sort_non_optimized(arr):
  n = len(arr)  # Tamanho da lista
  # Percorrendo a lista
  for i in range(n):
    for j in range(0, n - 1):
      # Comparando elementos adjacentes
      if arr[j] > arr[j + 1]:
        # Trocando elementos se estiverem fora de ordem
        arr[j], arr[j + 1] = arr[j + 1], arr[j]

# %% [markdown]
# - def `bubble_sort_non_optimized(arr):`: Declaração de uma função chamada bubble_sort_non_optimized, que recebe uma lista `arr` como argumento.
#
# - `n = len(arr)`: Calcula o tamanho da lista `arr` e atribui esse valor à variável `n`.
#
# - `for i in range(n):`: Primeiro *loop* *for*, que percorre a lista. O *loop* é executado `n` vezes, onde `n` é o tamanho da lista.
#
# - `for j in range(0, n - 1):`: Segundo *loop* *for* aninhado, que percorre a lista novamente. O *loop* é executado $n - 1$ vezes.
#
# - `if arr[j] > arr[j + 1]:`: Verifica se o elemento atual (`arr[j]`) é maior que o próximo elemento (`arr[j + 1]`) na lista. Se a condição for verdadeira, significa que os elementos estão fora de ordem.
#
# - `arr[j], arr[j + 1] = arr[j + 1], arr[j]`: Realiza a troca de posições entre os elementos `arr[j]` e `arr[j + 1]`, utilizando a técnica de atribuição múltipla. Isso coloca o elemento maior em uma posição posterior na lista, corrigindo a ordem.

# %% [markdown]
# #### **Segunda Implementação (otimizada)**

# %% [markdown]
# É possível perceber que, a cada iteração, um número é "empurrado" para o final da lista, encontrando a sua posição ordenada. Consequentemente, durante as iterações subsequentes, o índice associado a esse número não necessita mais ser comparado, uma vez que sua posição já está estabelecida. Em termos mais específicos, à medida que o algoritmo progride, o tamanho efetivo da lista a ser considerada diminui, garantindo que cada iteração resulte em um índice a menos que requer análise. Isso é particularmente evidente na otimização que foi implementada no segundo loop for:

# %%
def bubble_sort_optimized(arr):
  n = len(arr)  # Tamanho da lista
  # Percorrendo a lista
  for i in range(n):
    # Últimos i elementos já estão ordenados, não precisamos compará-los novamente
    for j in range(0, n - 1 - i):
      # Comparando elementos adjacentes
      if arr[j] > arr[j + 1]:
        # Trocando elementos se estiverem fora de ordem
        arr[j], arr[j + 1] = arr[j + 1], arr[j]

# %% [markdown]
# #### **Terceira Implementação (recursiva)**

# %% [markdown]
# Não é a abordagem mais eficiente para esse algoritmo, uma vez que ele já é ineficiente em sua forma iterativa. No entanto, se você estiver interessado em ver como poderia ser feita uma implementação recursiva do *Bubble Sort*, aqui está um exemplo:

# %%
def recursive_bubble_sort(arr, n):
  # Base case: se a lista estiver vazia ou com apenas um elemento, ela já está ordenada
  if n <= 1:
    return

  # Percorre a lista, comparando elementos adjacentes e fazendo trocas se necessário
  for i in range(n - 1):
    if arr[i] > arr[i + 1]:
      arr[i], arr[i + 1] = arr[i + 1], arr[i]

  # Chama a função recursiva com um tamanho reduzido da lista
  recursive_bubble_sort(arr, n - 1)

# %% [markdown]
# - `def recursive_bubble_sort(arr, n):`: Declaração de uma função que recebe uma lista `arr` e um valor `n` que representa o tamanho da parte da lista a ser considerada.
#
# - `if n <= 1:`: Verifica se o valor de `n` é menor ou igual a $1$. Se isso for verdade, a função retorna imediatamente, indicando que a lista já está ordenada (base case da recursão).
#
# - `for i in range(n - 1):`: *Loop* for que percorre a parte da lista a ser considerada, exceto o último elemento. O loop compara e troca elementos adjacentes, se necessário.
#
# - `if arr[i] > arr[i + 1]:`: Verifica se o elemento atual (`arr[i]`) é maior que o próximo elemento (`arr[i + 1]`) na lista. Se a condição for verdadeira, realiza a troca de posições entre os elementos, colocando o maior elemento em uma posição posterior.
#
# - `arr[i], arr[i + 1] = arr[i + 1], arr[i]`: Realiza a troca de posições entre os elementos `arr[i]` e `arr[i + 1]`, usando a técnica de atribuição múltipla.
#
# - `recursive_bubble_sort(arr, n - 1)`: Chama a função `recursive_bubble_sort` recursivamente, reduzindo o tamanho da parte da lista a ser considerada em $1$ unidade. Isso continua o processo de ordenação até que a lista esteja totalmente ordenada.

# %% [markdown]
# **Obs**: pode levar a problemas de estouro de pilha para listas maiores, já que uma chamada recursiva é feita para cada passagem pelo conjunto de elementos.

# %% [markdown]
# ### **Exemplo de Uso**

# %%
numbers = [64, 34, 25, 12, 22, 11, 90]
print("Lista original:", numbers)
bubble_sort_optimized(numbers)
print("Lista ordenada:", numbers)
# Out:
# Lista original: [64, 34, 25, 12, 22, 11, 90]
# Lista ordenada: [11, 12, 22, 25, 34, 64, 90]

# %% [markdown]
# ### **Análise do Tempo**

# %% [markdown]
# Abaixo está o gráfico comparativo do tempo gasto pelas três diferentes implementações do *Bubble Sort*.

# %%
import time
import matplotlib.pyplot as plt

# Gerar listas de tamanhos diferentes para a análise
list_lengths = [100, 200, 300, 400, 500, 600, 700, 800, 900]
timings_non_optimized = []
timings_optimized = []
timings_recursive = []

for length in list_lengths:
    data = list(range(length, 0, -1))  # Lista decrescente

    start_time = time.time()
    bubble_sort_non_optimized(data.copy())
    end_time = time.time()
    timings_non_optimized.append(end_time - start_time)

    start_time = time.time()
    bubble_sort_optimized(data.copy())
    end_time = time.time()
    timings_optimized.append(end_time - start_time)

    start_time = time.time()
    recursive_bubble_sort(data.copy(), length)
    end_time = time.time()
    timings_recursive.append(end_time - start_time)

# Plotar os resultados
plt.plot(list_lengths, timings_non_optimized, label='Não Otimizado')
plt.plot(list_lengths, timings_optimized, label='Otimizado')
plt.plot(list_lengths, timings_recursive, label='Recursivo')
plt.xlabel('Tamanho da Lista')
plt.ylabel('Tempo (segundos)')
plt.title('Comparação de Tempo - Bubble Sort Implementações')
plt.legend()
plt.show()

# %% [markdown]
# ### **Complexidade**

# %% [markdown]
# A tabela a seguir apresenta o número de comparações realizadas em cada passagem do algoritmo *Bubble Sort*, considerando um total de $𝑛$ elementos a serem ordenados. Conforme o processo avança, o número de comparações diminui progressivamente, já que a maior parte dos elementos já estará corretamente posicionada. O número total de passagens é $𝑛−1$, e o número de comparações em cada passagem decresce de acordo com os valores descritos. Isso reflete a natureza do *Bubble Sort*, onde a maior parte das trocas necessárias ocorre nas primeiras passagens, diminuindo gradualmente à medida que a lista se torna mais ordenada.

# %% [markdown]
# | Passagem | Comparações |
# | --- | --- |
# | $1$ | $n-1$ |
# | $2$ | $n-2$ |
# | $3$ | $n-3$ |
# | ... | ... |
# | $n-1$ | $1$ |

# %% [markdown]
# - $𝑛−1$ passagens serão realizadas para ordenar uma lista de tamanho $𝑛$;
# - A soma das comparações é uma PA: $𝑛-1 + 𝑛-2 + 𝑛-3 + ... + 3 + 2 + 1$;
# - Lembre-se de que essa soma pode ser calculada como: $𝑛²/2 - 𝑛/2$;
#   - para $𝑛 = 4$, temos $𝑛²/2 = 8$ e $𝑛/2 = 2$.
#   - para $𝑛 = 1000$, temos $𝑛²/2 = 500.000$ e $𝑛/2 = 500$.
# - Ou seja, $𝑂(𝑛²)$ comparações.
#
# **Obs**: Embora o *Bubble Sort* seja ineficiente em cenários de grande escala, ele ainda é útil quando o conjunto de dados está quase ordenado. Isso ocorre porque o número de trocas será menor e, em muitos casos, será mais rápido do que outros algoritmos mais sofisticados.

# %% [markdown]
# ### **Vantagens e Limitações**

# %% [markdown]
# #### **Vantagens**:

# %% [markdown]
# - Fácil de entender e implementar.
# - Útil para ilustrar os conceitos básicos de ordenação.
# - Pode ser útil para listas pequenas ou quase ordenadas.

# %% [markdown]
# #### **Limitações**:

# %% [markdown]
# - Complexidade quadrática no pior caso (não eficiente para grandes conjuntos de dados).
# - Muitas comparações e trocas, mesmo em casos ideais.

# %% [markdown]
# ### **Conclusão**

# %% [markdown]
# O *Bubble Sort* é um algoritmo simples que introduz conceitos essenciais de ordenação. Embora não seja adequado para uso prático em grandes conjuntos de dados, é uma ótima ferramenta educacional para entender como os algoritmos de ordenação funcionam. A partir deste ponto, os alunos podem se aprofundar em algoritmos mais eficientes, enquanto apreciam a base que o *Bubble Sort* fornece.

# %% [markdown]
# ###**Exercícios**

# %% [markdown]
# 1. Implemente uma função em *Python* que recebe uma lista de números como entrada e retorna o número total de comparações realizadas pelo *Bubble Sort* para ordenar a lista. Faça isso para as duas primeiras implementações (não otimizada e otimizada). Em seguida, gere um gráfico comparativo mostrando como o número de comparações varia em relação ao tamanho da entrada.

# %% [markdown]
# 2. Pesquise e implemente uma versão otimizada do *Bubble Sort* conhecida como "*Bubble Sort* com *Flag*". Essa variação evita passagens adicionais se a lista já estiver ordenada antes do término das iterações. Compare essa versão com as duas primeiras implementações, gerando um gráfico comparativo mostrando como o número de comparações varia em relação ao tamanho da entrada.
